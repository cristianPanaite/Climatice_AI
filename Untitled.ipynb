# %%
# data loading

from keras.preprocessing.image import ImageDataGenerator
# create generator
datagen = ImageDataGenerator(rescale=1/255)
# prepare an iterators for each dataset
train_it = datagen.flow_from_directory('dataset/train/', class_mode='categorical', target_size=(32, 32))
test_it = datagen.flow_from_directory('dataset/test/', class_mode='categorical', target_size=(32, 32))
# confirm the iterator works
batchX, batchy = train_it.next()
print('Batch shape=%s, min=%.3f, max=%.3f' % (batchX.shape, batchX.min(), batchX.max()))
# Out:
# Found 10901 images belonging to 6 classes.
# Found 2698 images belonging to 6 classes.
# Batch shape=(32, 32, 32, 3), min=0.000, max=1.000

# %%
from tensorflow.python.keras import layers
import tensorflow as tf
from tensorflow.python.keras.engine.keras_tensor import KerasTensor
# model

def residual(x: KerasTensor, num_channel: int) -> KerasTensor:
    """A ResNet unit for ResNet9.
    Args:
        x: Input Keras tensor.
        num_channel: The number of layer channel.
    Return:
        Output Keras tensor.
    """
    x = layers.Conv2D(num_channel, 3, padding='same')(x)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU(alpha=0.1)(x)
    x = layers.Conv2D(num_channel, 3, padding='same')(x)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU(alpha=0.1)(x)
    return x

def create_model():
    inp = layers.Input(shape=(32, 32, 3))
    x = layers.Conv2D(64, 3, padding='same')(inp)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU(alpha=0.1)(x)
    # layer1
    x = layers.Conv2D(128, 3, padding='same')(x)
    x = layers.MaxPool2D()(x)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU(alpha=0.1)(x)
    x = layers.Add()([x, residual(x, 128)])
    # layer2
    x = layers.Conv2D(256, 3, padding='same')(x)
    x = layers.MaxPool2D()(x)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU(alpha=0.1)(x)
    # layer3
    x = layers.Conv2D(512, 3, padding='same')(x)
    x = layers.MaxPool2D()(x)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU(alpha=0.1)(x)
    x = layers.Add()([x, residual(x, 512)])
    # layers4
    x = layers.GlobalMaxPool2D()(x)
    x = layers.Flatten()(x)
    x = layers.Dense(6)(x)
    x = layers.Activation('softmax', dtype='float32')(x)
    model = tf.keras.Model(inputs=inp, outputs=x)

    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 32, 32, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 128)  73856       leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 128)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16, 16, 128)  512         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 16, 16, 128)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 128)  147584      leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 16, 16, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 128)  147584      leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 16, 16, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 16, 16, 128)  0           leaky_re_lu_1[0][0]
#                                                                  leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 256)  295168      add[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 256)    0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 8, 256)    1024        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 8, 8, 256)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 512)    1180160     leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 4, 4, 512)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 4, 4, 512)    2048        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 4, 4, 512)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 4, 4, 512)    2359808     leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 4, 4, 512)    2048        conv2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 4, 4, 512)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 4, 4, 512)    2359808     leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 512)    2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 4, 4, 512)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 4, 4, 512)    0           leaky_re_lu_5[0][0]
#                                                                  leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d (GlobalMax (None, 512)          0           add_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           global_max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 6)            3078        flatten[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 6)            0           dense[0][0]
# ==================================================================================================
# Total params: 6,577,798
# Trainable params: 6,573,318
# Non-trainable params: 4,480
# __________________________________________________________________________________________________

# %%
# compiling the sequential model
from keras.utils import np_utils

# to calculate accuracy
from sklearn.metrics import accuracy_score


model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

history = model.fit(train_it, epochs=10, validation_data=test_it, verbose = 1)
# Out:
# Epoch 1/10
# 341/341 [==============================] - 135s 392ms/step - loss: 0.5038 - accuracy: 0.8463 - val_loss: 0.4076 - val_accuracy: 0.8792
# Epoch 2/10
# 341/341 [==============================] - 131s 384ms/step - loss: 0.1922 - accuracy: 0.9330 - val_loss: 0.1320 - val_accuracy: 0.9529
# Epoch 3/10
# 341/341 [==============================] - 129s 377ms/step - loss: 0.1217 - accuracy: 0.9562 - val_loss: 0.1035 - val_accuracy: 0.9622
# Epoch 4/10
# 341/341 [==============================] - 131s 385ms/step - loss: 0.0891 - accuracy: 0.9688 - val_loss: 0.1162 - val_accuracy: 0.9548
# Epoch 5/10
# 341/341 [==============================] - 130s 380ms/step - loss: 0.0611 - accuracy: 0.9789 - val_loss: 0.1046 - val_accuracy: 0.9659
# Epoch 6/10
# 341/341 [==============================] - 133s 390ms/step - loss: 0.0510 - accuracy: 0.9809 - val_loss: 0.4816 - val_accuracy: 0.8799
# Epoch 7/10
# 341/341 [==============================] - 134s 393ms/step - loss: 0.0610 - accuracy: 0.9796 - val_loss: 0.0443 - val_accuracy: 0.9852
# Epoch 8/10
# 341/341 [==============================] - 153s 448ms/step - loss: 0.0377 - accuracy: 0.9885 - val_loss: 0.0355 - val_accuracy: 0.9870
# Epoch 9/10
# 341/341 [==============================] - 164s 481ms/step - loss: 0.0232 - accuracy: 0.9930 - val_loss: 0.4036 - val_accuracy: 0.9040
# Epoch 10/10
# 341/341 [==============================] - 130s 380ms/step - loss: 0.0675 - accuracy: 0.9777 - val_loss: 0.0534 - val_accuracy: 0.9826

# %%
import matplotlib.pyplot as plt
import numpy
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

Y_pred = model.predict(test_it, test_it.samples // test_it.batch_size + 1, verbose = 1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
cf = confusion_matrix(test_it.classes, y_pred)
print(confusion_matrix(test_it.classes, y_pred))
print('Classification Report')
target_names = list(test_it.class_indices.keys())
print(test_it.class_indices.keys())
print(classification_report(test_it.classes, y_pred, target_names=target_names))
# Out:
# 85/85 [==============================] - 9s 106ms/step
# Confusion Matrix
# [[ 76  43  55  93  71  57]
#  [ 53  63  48  70  77  70]
#  [ 61  60  61  76  81  49]
#  [ 79  86 101 115 118 102]
#  [ 86  66  68 128 105  77]
#  [ 56  63  61  95  73  55]]
# Classification Report
# dict_keys(['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges'])
#                precision    recall  f1-score   support
#
#   freshapples       0.18      0.19      0.19       395
#   freshbanana       0.17      0.17      0.17       381
#  freshoranges       0.15      0.16      0.16       388
#  rottenapples       0.20      0.19      0.20       601
#  rottenbanana       0.20      0.20      0.20       530
# rottenoranges       0.13      0.14      0.14       403
#
#      accuracy                           0.18      2698
#     macro avg       0.17      0.17      0.17      2698
#  weighted avg       0.18      0.18      0.18      2698

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

df_cm = pd.DataFrame(cf, index = [i for i in target_names], columns= [i for i in target_names])

plt.figure(figsize=(10, 7))
sn.heatmap(df_cm, annot=True, fmt='g')
# Out:
# <AxesSubplot:>
