# %%
# data loading

from keras.preprocessing.image import ImageDataGenerator
# create generator
datagen = ImageDataGenerator()
# prepare an iterators for each dataset
train_it = datagen.flow_from_directory('dataset/train/', class_mode='categorical', target_size=(32,32))
test_it = datagen.flow_from_directory('dataset/test/', class_mode='categorical', target_size=(32,32))
# confirm the iterator works
batchX, batchy = train_it.next()
print('Batch shape=%s, min=%.3f, max=%.3f' % (batchX.shape, batchX.min(), batchX.max()))
# Out:
# Found 10901 images belonging to 6 classes.
# Found 2698 images belonging to 6 classes.
# Batch shape=(32, 32, 32, 3), min=0.000, max=255.000

# %%
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.applications.resnet50 import ResNet50

## Loading VGG16 model-
base_model = ResNet50(weights=None, include_top=False, input_shape=(32, 32, 3))
base_model.trainable = False ## Not trainable weights

# %%
from tensorflow.keras import layers, models

flatten_layer = layers.Flatten()
dense_layer_1 = layers.Dense(50, activation='relu')
dense_layer_2 = layers.Dense(20, activation='relu')
prediction_layer = layers.Dense(6, activation='softmax')


model = models.Sequential([
    base_model,
    flatten_layer,
    dense_layer_1,
    dense_layer_2,
    prediction_layer
])

# %%
from tensorflow.keras.callbacks import EarlyStopping

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'],
)


history = model.fit(train_it, epochs=10, validation_data=test_it, verbose = 1)
# Out:
# Epoch 1/10
# 341/341 [==============================] - 73s 204ms/step - loss: 1.7836 - accuracy: 0.3234 - val_loss: 1.5570 - val_accuracy: 0.3740
# Epoch 2/10
# 341/341 [==============================] - 63s 184ms/step - loss: 1.4210 - accuracy: 0.3989 - val_loss: 1.4166 - val_accuracy: 0.4010
# Epoch 3/10
# 341/341 [==============================] - 60s 177ms/step - loss: 1.3301 - accuracy: 0.4228 - val_loss: 1.4421 - val_accuracy: 0.4522
# Epoch 4/10
# 341/341 [==============================] - 57s 166ms/step - loss: 1.2398 - accuracy: 0.4700 - val_loss: 1.4147 - val_accuracy: 0.3973
# Epoch 5/10
# 341/341 [==============================] - 58s 171ms/step - loss: 1.2038 - accuracy: 0.4933 - val_loss: 1.1445 - val_accuracy: 0.5089
# Epoch 6/10
# 341/341 [==============================] - 58s 169ms/step - loss: 1.1652 - accuracy: 0.5184 - val_loss: 1.1518 - val_accuracy: 0.5448
# Epoch 7/10
# 341/341 [==============================] - 57s 168ms/step - loss: 1.1360 - accuracy: 0.5317 - val_loss: 1.3822 - val_accuracy: 0.4229
# Epoch 8/10
# 341/341 [==============================] - 57s 169ms/step - loss: 1.0911 - accuracy: 0.5498 - val_loss: 1.1540 - val_accuracy: 0.5437
# Epoch 9/10
# 341/341 [==============================] - 57s 167ms/step - loss: 1.0103 - accuracy: 0.5844 - val_loss: 1.0109 - val_accuracy: 0.5849
# Epoch 10/10
# 341/341 [==============================] - 58s 169ms/step - loss: 0.9934 - accuracy: 0.5954 - val_loss: 1.0257 - val_accuracy: 0.5752

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 1, 1, 2048)        23587712
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 50)                102450
#
#  dense_1 (Dense)             (None, 20)                1020
#
#  dense_2 (Dense)             (None, 6)                 126
#
# =================================================================
# Total params: 23,691,308
# Trainable params: 103,596
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
import numpy
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

Y_pred = model.predict(test_it, test_it.samples // test_it.batch_size + 1, verbose = 1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
cf = confusion_matrix(test_it.classes, y_pred)
print(confusion_matrix(test_it.classes, y_pred))
print('Classification Report')
target_names = ['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']
print(classification_report(test_it.classes, y_pred, target_names=target_names))
# Out:
# 85/85 [==============================] - 12s 129ms/step
# Confusion Matrix
# [[ 29  82  44  73  98  69]
#  [ 20  67  39 108  88  59]
#  [ 33  76  32  90  91  66]
#  [ 44 117  71 138 151  80]
#  [ 36 109  54 120 136  75]
#  [ 34  72  33 100 110  54]]
# Classification Report
#                precision    recall  f1-score   support
#
#   freshapples       0.15      0.07      0.10       395
#   freshbanana       0.13      0.18      0.15       381
#  freshoranges       0.12      0.08      0.10       388
#  rottenapples       0.22      0.23      0.22       601
#  rottenbanana       0.20      0.26      0.23       530
# rottenoranges       0.13      0.13      0.13       403
#
#      accuracy                           0.17      2698
#     macro avg       0.16      0.16      0.15      2698
#  weighted avg       0.17      0.17      0.16      2698

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

df_cm = pd.DataFrame(cf, index = [i for i in target_names], columns= [i for i in target_names])

plt.figure(figsize=(10, 7))
sn.heatmap(df_cm, annot=True, fmt='g')
# Out:
# <AxesSubplot:>
